# %%
def createlinks(start,end):
    base = 'https://en.wikipedia.org/wiki/'
    tails=[]
    for i in range(int(start),int(end)):
        tails.append('{}_Mosconi_Cup'.format(i))
    links=[base+tail for tail in tails]
    return(links)

# %%
def createtables(url):
    page = requests.get(url)
    tree = html.fromstring(page.text)
    tables = tree.xpath('//table')
    tables=[table for table in tables if(table[0].text_content().replace('\n','')=='Results')]
    return(tables)

# %%
def createdf(tables):
    import re
    l=[]
    col=['Format','European_player','European_score','American_score','American_player']

    for i in range(len(tables)+1):
        for j in range(1,6):
            try:
                element=tables[i][j].text_content().replace("\n", " ")
                match = re.match(r"\s?(\w+)\s(.+)\s([0-9])[–]([0-9])\s?\w+\s?(.+)\s", element)
                if match:
                    l.append(list(match.groups()))
            except:
                pass
    df=pd.DataFrame(l,columns=col)
    return(df)

# %%
def createdf_bw(tables):
    import re
    l=[]
    col=['Format','European_player','European_score','American_score','American_player']

    for i in range(len(tables)+1):
        for j in range(1,6):
            try:
                element=tables[i][j].text_content().replace("\n", " ")
                match = re.match(r"\s?(\w+)\s(.+)\s([0-9])[–]([0-9])\s?\w+\s?(.+)\s", element)
                if match:
                    print('ok')
                    lst=[match.group(1), match.group(5), match.group(4), match.group(3), match.group(2)]
                    print(lst)
                    l.append(lst)
                else:
                    print('fail')
            except:
                pass
    print(l)
    df=pd.DataFrame(l,columns=col)
    return(df)

# %%
def main():
    from lxml import html
    import requests
    import pandas as pd
    df = pd.DataFrame()
    links = createlinks('1998','2014')
    for url in links:
        tables = createtables(url)
        newdf = createdf(tables) 
        df=df.append(newdf)
    return(df)

# %%
def main_bw():
    from lxml import html
    import requests
    import pandas as pd
    df = pd.DataFrame()
    links = createlinks('2015','2016')
    for url in links:
        tables = createtables(url)
        newdf = createdf_bw(tables) 
        df=df.append(newdf)
    return(df)

# %%
df2015= main_bw()
# Out:
# ok
# ['Teams', 'Team Europe', '4', '5', 'Team USA']
# ok
# ['Doubles', 'Karl Boyes Nick van den Berg', '5', '4', 'Corey Deuel Mike Dechaine']
# ok
# ['Singles', 'Niels Feijen', '5', '2', 'Justin Bergman']
# ok
# ['Doubles', 'Darren Appleton Albin Ouschan', '1', '5', 'Shane Van Boening Skyler Woodward']
# ok
# ['Singles', 'Darren Appleton', '5', '1', 'Shane Van Boening']
# ok
# ['Doubles', 'Niels Feijen Nick van den Berg', '3', '5', 'Justin Bergman Skyler Woodward']
# ok
# ['Singles', 'Albin Ouschan', '5', '3', 'Mike Dechaine']
# ok
# ['Doubles', 'Darren Appleton Karl Boyes', '5', '2', 'Shane Van Boening Corey Deuel']
# ok
# ['Singles', 'Karl Boyes', '5', '3', 'Skyler Woodward']
# ok
# ['Doubles', 'Darren Appleton Nick van den Berg', '4', '5', 'Shane Van Boening Mike Dechaine']
# ok
# ['Doubles', 'Niels Feijen Albin Ouschan', '5', '1', 'Justin Bergman Corey Deuel']
# ok
# ['Singles', 'Nick van den Berg', '4', '5', 'Corey Deuel']
# ok
# ['Doubles', 'Karl Boyes Albin Ouschan', '5', '2', 'Mike Dechaine Skyler Woodward']
# ok
# ['Singles', 'Niels Feijen', '5', '4', 'Shane Van Boening']
# ok
# ['Singles', 'Darren Appleton', '2', '5', 'Justin Bergman']
# ok
# ['Singles', 'Niels Feijen', '5', '4', 'Justin Bergman']
# ok
# ['Singles', 'Karl Boyes', '4', '5', 'Shane Van Boening']
# ok
# ['Singles', 'Albin Ouschan', '5', '4', 'Skyler Woodward']
# fail
# fail
# [['Teams', 'Team Europe', '4', '5', 'Team USA'], ['Doubles', 'Karl Boyes Nick van den Berg', '5', '4', 'Corey Deuel Mike Dechaine'], ['Singles', 'Niels Feijen', '5', '2', 'Justin Bergman'], ['Doubles', 'Darren Appleton Albin Ouschan', '1', '5', 'Shane Van Boening Skyler Woodward'], ['Singles', 'Darren Appleton', '5', '1', 'Shane Van Boening'], ['Doubles', 'Niels Feijen Nick van den Berg', '3', '5', 'Justin Bergman Skyler Woodward'], ['Singles', 'Albin Ouschan', '5', '3', 'Mike Dechaine'], ['Doubles', 'Darren Appleton Karl Boyes', '5', '2', 'Shane Van Boening Corey Deuel'], ['Singles', 'Karl Boyes', '5', '3', 'Skyler Woodward'], ['Doubles', 'Darren Appleton Nick van den Berg', '4', '5', 'Shane Van Boening Mike Dechaine'], ['Doubles', 'Niels Feijen Albin Ouschan', '5', '1', 'Justin Bergman Corey Deuel'], ['Singles', 'Nick van den Berg', '4', '5', 'Corey Deuel'], ['Doubles', 'Karl Boyes Albin Ouschan', '5', '2', 'Mike Dechaine Skyler Woodward'], ['Singles', 'Niels Feijen', '5', '4', 'Shane Van Boening'], ['Singles', 'Darren Appleton', '2', '5', 'Justin Bergman'], ['Singles', 'Niels Feijen', '5', '4', 'Justin Bergman'], ['Singles', 'Karl Boyes', '4', '5', 'Shane Van Boening'], ['Singles', 'Albin Ouschan', '5', '4', 'Skyler Woodward']]

# %%
df=main()

# %%
df2015
# Out:
#      Format                    European_player European_score American_score  \
# 0     Teams                        Team Europe              4              5
# 1   Doubles       Karl Boyes Nick van den Berg              5              4
# 2   Singles                       Niels Feijen              5              2
# 3   Doubles      Darren Appleton Albin Ouschan              1              5
# 4   Singles                    Darren Appleton              5              1
# 5   Doubles     Niels Feijen Nick van den Berg              3              5
# 6   Singles                      Albin Ouschan              5              3
# 7   Doubles         Darren Appleton Karl Boyes              5              2
# 8   Singles                         Karl Boyes              5              3
# 9   Doubles  Darren Appleton Nick van den Berg              4              5
# 10  Doubles         Niels Feijen Albin Ouschan              5              1
# 11  Singles                  Nick van den Berg              4              5
# 12  Doubles           Karl Boyes Albin Ouschan              5              2
# 13  Singles                       Niels Feijen              5              4
# 14  Singles                    Darren Appleton              2              5
# 15  Singles                       Niels Feijen              5              4
# 16  Singles                         Karl Boyes              4              5
# 17  Singles                      Albin Ouschan              5              4
#
#                       American_player
# 0                            Team USA
# 1           Corey Deuel Mike Dechaine
# 2                      Justin Bergman
# 3   Shane Van Boening Skyler Woodward
# 4                   Shane Van Boening
# 5      Justin Bergman Skyler Woodward
# 6                       Mike Dechaine
# 7       Shane Van Boening Corey Deuel
# 8                     Skyler Woodward
# 9     Shane Van Boening Mike Dechaine
# 10         Justin Bergman Corey Deuel
# 11                        Corey Deuel
# 12      Mike Dechaine Skyler Woodward
# 13                  Shane Van Boening
# 14                     Justin Bergman
# 15                     Justin Bergman
# 16                  Shane Van Boening
# 17                    Skyler Woodward

# %%
frames=[df,df2015]
df=pd.concat(frames)

# %%
df.shape
# Out:
# (333, 6)

# %%
pkl=r'C:\Users\andrew\Desktop\mosconi\mosconi_1998_2015_pkls'
df.to_pickle(pkl)

# %%
pkl=r'C:\Users\andrew\Desktop\mosconi\mosconi_1998_2014_pkls'
df.to_pickle(pkl)

# %% [markdown]
# Missing 2014 data. Can get it from: http://www.matchroompool.com/mosconi-cup/mosconi-cup-xxi/#fixtures
# compare stats here:
# http://forums.azbilliards.com/showthread.php?t=439775&page=4

# %%
import re
l=[]
with open('manual_scrape_cleaned_2014.txt','r') as rf:
    for line in rf:
        match = re.match(r"(\w+)\s(.+)\s([0-9])\s?[-]\s?([0-9])\s?(.+)", line)
        if match:
            l.append(list(match.groups()))

# %%
df=pd.read_pickle(pkl)

# %%
df2=pd.DataFrame(l,columns=col)

# %%
frames=[df,df2]
df=pd.concat(frames)

# %%
df['Europe_won']=df.European_score>df.American_score

# %%
df.shape
# Out:
# (315, 6)

# %%
pkl=r'C:\Users\andrew\Desktop\mosconi\mosconi_1998_2014_inc_pkls'
df.to_pickle(pkl)

# %%
df['Europe_won']=df.European_score>df.American_score

# %%
cols= ['Format','European_player','European_score','American_score','American_player','Europe_won']
df=df[cols]
df
# Out:
#      Format                        European_player European_score  \
# 0   Doubles              Mika Immonen Ralf Souquet              7
# 1   Doubles            Oliver Ortmann Steve Knight              7
# 2   Doubles              Fabio Petroni Steve Davis              5
# 3   Doubles              Mika Immonen Ralf Souquet              7
# 4   Doubles              Steve Davis Fabio Petroni              3
# 5   Doubles            Oliver Ortmann Steve Knight              7
# 6   Singles                         Oliver Ortmann              3
# 7   Singles                           Steve Knight              3
# 8   Singles                           Mika Immonen              4
# 9   Singles                           Ralf Souquet              7
# 10  Doubles            Steve Knight Oliver Ortmann              6
# 11  Doubles              Ralf Souquet Mika Immonen              5
# 12  Doubles              Steve Davis Fabio Petroni              7
# 13  Singles                            Steve Davis              2
# 14  Singles                          Fabio Petroni              5
# 15  Singles                           Mika Immonen              4
# 16  Singles                           Ralf Souquet              7
# 17  Singles                         Oliver Ortmann              4
# 18  Singles                           Steve Knight              7
# 19  Singles                            Steve Davis              7
# 20  Singles                          Fabio Petroni              5
# 21  Singles                           Ralf Souquet              4
# 0   Doubles              Mika Immonen Ralf Souquet              2
# 1   Doubles               Oliver Ortmann Alex Lely              2
# 2   Doubles               Steve Davis Steve Knight              4
# 3   Doubles            Ralf Souquet Oliver Ortmann              5
# 4   Doubles              Steve Knight Mika Immonen              5
# 5   Doubles                  Steve Davis Alex Lely              5
# 6   Singles                              Alex Lely              4
# 7   Singles                           Ralf Souquet              5
# ..      ...                                    ...            ...
# 4   Singles                        Darren Appleton              5
# 5   Doubles               Niels Feijen & Mark Gray              2
# 6   Singles                             Karl Boyes              5
# 7   Doubles  Darren Appleton & Nikos Ekonomopoulos              5
# 8   Singles                           Niels Feijen              5
# 9   Doubles            Darren Appleton & Mark Gray              4
# 10  Doubles       Nikos Ekonomopoulos & Karl Boyes              5
# 11  Singles                    Nikos Ekonomopoulos              3
# 12  Doubles                 Mark Gray & Karl Boyes              5
# 13  Singles                           Niels Feijen              5
# 14  Singles                        Darren Appleton              5
# 15  Singles                    Nikos Ekonomopoulos              5
# 0     Teams                            Team Europe              4
# 1   Doubles           Karl Boyes Nick van den Berg              5
# 2   Singles                           Niels Feijen              5
# 3   Doubles          Darren Appleton Albin Ouschan              1
# 4   Singles                        Darren Appleton              5
# 5   Doubles         Niels Feijen Nick van den Berg              3
# 6   Singles                          Albin Ouschan              5
# 7   Doubles             Darren Appleton Karl Boyes              5
# 8   Singles                             Karl Boyes              5
# 9   Doubles      Darren Appleton Nick van den Berg              4
# 10  Doubles             Niels Feijen Albin Ouschan              5
# 11  Singles                      Nick van den Berg              4
# 12  Doubles               Karl Boyes Albin Ouschan              5
# 13  Singles                           Niels Feijen              5
# 14  Singles                        Darren Appleton              2
# 15  Singles                           Niels Feijen              5
# 16  Singles                             Karl Boyes              4
# 17  Singles                          Albin Ouschan              5
#
#    American_score                    American_player Europe_won
# 0               5          Johnny Archer Nick Varner       True
# 1               6        James Rempe Earl Strickland       True
# 2               7          Kim Davenport Reed Pierce      False
# 3               3        James Rempe Earl Strickland       True
# 4               7          Nick Varner Johnny Archer      False
# 5               5          Kim Davenport Reed Pierce       True
# 6               7                      Johnny Archer      False
# 7               7                    Earl Strickland      False
# 8               7                        Reed Pierce      False
# 9               1                        Nick Varner       True
# 10              7      Earl Strickland Kim Davenport      False
# 11              7          Johnny Archer Nick Varner      False
# 12              2            Reed Pierce James Rempe       True
# 13              7                      Kim Davenport      False
# 14              7                        James Rempe      False
# 15              7                    Earl Strickland      False
# 16              5                      Johnny Archer       True
# 17              7                        Reed Pierce      False
# 18              6                        Nick Varner       True
# 19              6                        James Rempe       True
# 20              7                      Kim Davenport      False
# 21              7                      Johnny Archer      False
# 0               5        Johnny Archer Kim Davenport      False
# 1               5        Earl Strickland James Rempe      False
# 2               5      Jeremy Jones Michael Coltrain      False
# 3               3        Johnny Archer Kim Davenport       True
# 4               2        Earl Strickland James Rempe       True
# 5               3      Jeremy Jones Michael Coltrain       True
# 6               5                      Kim Davenport      False
# 7               2                    Earl Strickland       True
# ..            ...                                ...        ...
# 4               3                  Shane Van Boening       True
# 5               5       Justin Hall & Justin Bergman      False
# 6               2                        Corey Deuel       True
# 7               2   Shane Van Boening & John Schmidt       True
# 8               3                     Justin Bergman       True
# 9               5    Shane Van Boening & Corey Deuel      False
# 10              3         John Schmidt & Justin Hall       True
# 11              5                        Justin Hall      False
# 12              3         Corey Deuel & John Schmidt       True
# 13              2                     Justin Bergman       True
# 14              2                  Shane Van Boening       True
# 15              2                  Shane Van Boening       True
# 0               5                           Team USA      False
# 1               4          Corey Deuel Mike Dechaine       True
# 2               2                     Justin Bergman       True
# 3               5  Shane Van Boening Skyler Woodward      False
# 4               1                  Shane Van Boening       True
# 5               5     Justin Bergman Skyler Woodward      False
# 6               3                      Mike Dechaine       True
# 7               2      Shane Van Boening Corey Deuel       True
# 8               3                    Skyler Woodward       True
# 9               5    Shane Van Boening Mike Dechaine      False
# 10              1         Justin Bergman Corey Deuel       True
# 11              5                        Corey Deuel      False
# 12              2      Mike Dechaine Skyler Woodward       True
# 13              4                  Shane Van Boening       True
# 14              5                     Justin Bergman      False
# 15              4                     Justin Bergman       True
# 16              5                  Shane Van Boening      False
# 17              4                    Skyler Woodward       True
#
# [333 rows x 6 columns]

# %%
pkl=r'C:\Users\andrew\Desktop\mosconi\mosconi_1998_2015_inc_pkls'
df.to_pickle(pkl)

# %%
svb = df['American_player'].str.contains('Shane Van Boening')

# %%
earl = df['American_player'].str.contains('Earl Strickland')

# %%
hatch = df['American_player'].str.contains('Dennis Hatch')

# %%
Ouschan = df['European_player'].str.contains('Albin Ouschan')

# %%
df[Ouschan]
# Out:
#      Format                European_player European_score American_score  \
# 3   Doubles  Darren Appleton Albin Ouschan              1              5
# 6   Singles                  Albin Ouschan              5              3
# 10  Doubles     Niels Feijen Albin Ouschan              5              1
# 12  Doubles       Karl Boyes Albin Ouschan              5              2
# 17  Singles                  Albin Ouschan              5              4
#
#                       American_player Europe_won
# 3   Shane Van Boening Skyler Woodward      False
# 6                       Mike Dechaine       True
# 10         Justin Bergman Corey Deuel       True
# 12      Mike Dechaine Skyler Woodward       True
# 17                    Skyler Woodward       True

# %%
Woodward = df['American_player'].str.contains('Woodward')

# %%
singles = df['Format']=='Singles'
doubles = df['Format']=='Doubles'
teams = df['Format']=='Teams'

# %%
europe_won = df['Europe_won'] == True
america_won = df['Europe_won'] == False

# %%
def singleswinloss(player,country):
    if 'a' in country:
        dfnew= df[df['American_player'].str.contains(player)]
        win=dfnew[america_won&singles].shape[0]
        loss=dfnew[player&~america_won&singles].shape[0]
    else:
        dfnew = df[df['European_player'].str.contains(player)]
        loss=dfnew[player&america_won&singles].shape[0]
        win=dfnew[player&~america_won&singles].shape[0]        
    wl='{}-{}'.format(win,loss)
    return(wl)
def doubleswinloss(player,country):
    if 'a' in country:
        win=df[player&america_won&doubles].shape[0]
        loss=df[player&~america_won&doubles].shape[0]
    else:
        loss=df[player&america_won&doubles].shape[0]
        win=df[player&~america_won&doubles].shape[0] 
    wl='{}-{}'.format(win,loss)
    return(wl)
def combinedwinloss(player,country):
    if 'a' in country:
        dwin=df[player&america_won&doubles].shape[0]
        dloss=df[player&~america_won&doubles].shape[0]
        swin=df[player&america_won&singles].shape[0]
        sloss=df[player&~america_won&singles].shape[0]
    else:
        dloss=df[player&america_won&doubles].shape[0]
        dwin=df[player&~america_won&doubles].shape[0]
        sloss=df[player&america_won&singles].shape[0]
        swin=df[player&~america_won&singles].shape[0]
    win=dwin+swin
    loss=dloss+sloss
    wl='{}-{}'.format(win,loss)
    return(wl)

# %%
singleswinloss('Earl','am')
# Out:
# c:\users\andrew\appdata\local\programs\python\python35\lib\site-packages\ipykernel\__main__.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-765-2451d37682d4> in <module>()
# ----> 1 singleswinloss('Earl','am')
#
# <ipython-input-764-0e9960500710> in singleswinloss(player, country)
#       2     if 'a' in country:
#       3         dfnew= df[df['American_player'].str.contains(player)]
# ----> 4         win=dfnew[america_won&singles].shape[0]
#       5         loss=dfnew[player&~america_won&singles].shape[0]
#       6     else:
#
# c:\users\andrew\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2051         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2052             # either boolean or fancy integer index
# -> 2053             return self._getitem_array(key)
#    2054         elif isinstance(key, DataFrame):
#    2055             return self._getitem_frame(key)
#
# c:\users\andrew\appdata\local\programs\python\python35\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2091             # check_bool_indexer will throw exception if Series key cannot
#    2092             # be reindexed to match DataFrame rows
# -> 2093             key = check_bool_indexer(self.index, key)
#    2094             indexer = key.nonzero()[0]
#    2095             return self.take(indexer, axis=0, convert=False)
#
# c:\users\andrew\appdata\local\programs\python\python35\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(ax, key)
#    1812     result = key
#    1813     if isinstance(key, ABCSeries) and not key.index.equals(ax):
# -> 1814         result = result.reindex(ax)
#    1815         mask = isnull(result._values)
#    1816         if mask.any():
#
# c:\users\andrew\appdata\local\programs\python\python35\lib\site-packages\pandas\core\series.py in reindex(self, index, **kwargs)
#    2360     @Appender(generic._shared_docs['reindex'] % _shared_doc_kwargs)
#    2361     def reindex(self, index=None, **kwargs):
# -> 2362         return super(Series, self).reindex(index=index, **kwargs)
#    2363
#    2364     @Appender(generic._shared_docs['fillna'] % _shared_doc_kwargs)
#
# c:\users\andrew\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    2257         # perform the reindex on the axes
#    2258         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 2259                                   fill_value, copy).__finalize__(self)
#    2260
#    2261     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# c:\users\andrew\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    2275             obj = obj._reindex_with_indexers({axis: [new_index, indexer]},
#    2276                                              fill_value=fill_value,
# -> 2277                                              copy=copy, allow_dups=False)
#    2278
#    2279         return obj
#
# c:\users\andrew\appdata\local\programs\python\python35\lib\site-packages\pandas\core\generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    2369                                                 fill_value=fill_value,
#    2370                                                 allow_dups=allow_dups,
# -> 2371                                                 copy=copy)
#    2372
#    2373         if copy and new_data is self._data:
#
# c:\users\andrew\appdata\local\programs\python\python35\lib\site-packages\pandas\core\internals.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    3837         # some axes don't allow reindexing with dups
#    3838         if not allow_dups:
# -> 3839             self.axes[axis]._can_reindex(indexer)
#    3840
#    3841         if axis >= self.ndim:
#
# c:\users\andrew\appdata\local\programs\python\python35\lib\site-packages\pandas\indexes\base.py in _can_reindex(self, indexer)
#    2492         # trying to reindex on an axis with duplicates
#    2493         if not self.is_unique and len(indexer):
# -> 2494             raise ValueError("cannot reindex from a duplicate axis")
#    2495
#    2496     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis

# %%
print(singleswinloss(Ouschan,'eu'),doubleswinloss(Ouschan,'eu'),combinedwinloss(Ouschan,'eu'))
# Out:
# 2-0 2-1 4-1

# %% [markdown]
# Need to get player list for both teams

# %%
with open('euro_players_scrape.txt', 'r') as rf:
    euro_players=[]
    for line in rf:
        n=line.split('  ')
        euro_players.append(n[0])
with open('am_players_scrape.txt', 'r') as rf:
    am_players=[]
    for line in rf:
        n=line.split('  ')
        am_players.append(n[0])

# %% [markdown]
# Year 2015 has the US players listed first. Must correct the entries into the df
