# %%
def createdic(start,end):
    dic={}
    for i in range(int(start),int(end)):
        dic[i]='https://en.wikipedia.org/wiki/{}_Mosconi_Cup'.format(i)
    return(dic)

# %%
def createtables(url):
    import requests
    from lxml import html
    page = requests.get(url)
    tree = html.fromstring(page.text)
    tables = tree.xpath('//table')
    tables=[table for table in tables if(table[0].text_content().replace('\n','')=='Results')]
    return(tables)

# %%
def tablelengths(tables):
    tl=[]
    for table in tables:
        tl.append(len(table)-3)
    return(tl)

# %%
def cdf(tables,tl,df):
    import pandas as pd
    import re
    l=[]
    col=['Format','European_player','European_score','American_score','American_player']

    for i,table in enumerate(tables):
        for j in range(tl[i]+1):
            try:
                element=tables[i][j].text_content().replace("\n", " ")
                match = re.match(r"\s?(\w+)\s(.+)\s([0-9])[–]([0-9])\s?\w+\s?(.+)\s", element)
                if match:
                    l.append(list(match.groups()))
            except:
                pass
    if df.empty:
        df=pd.DataFrame(l,columns=col)
    else:
        new = pd.DataFrame(l, columns = col)
        frames = (df,new)
        df = pd.concat(frames)
    return(df)

# %%
def newmain():
    col=['Format','European_player','European_score','American_score','American_player']
    df = pd.DataFrame(columns = col)
    for link in links:
        tables = createtables(link)
        tl = tablelengths(tables)
        df = cdf(tables,tl,df)
    return(df)

# %% [markdown]
# Missing 2014 data. Can get it from: http://www.matchroompool.com/mosconi-cup/mosconi-cup-xxi/#fixtures
# compare stats here:
# http://forums.azbilliards.com/showthread.php?t=439775&page=4

# %%
import re
l=[]
with open('manual_scrape_cleaned_2014.txt','r') as rf:
    for line in rf:
        match = re.match(r"(\w+)\s(.+)\s([0-9])\s?[-]\s?([0-9])\s?(.+)", line)
        if match:
            l.append(list(match.groups()))

# %%
df=pd.read_pickle(pkl)

# %%
df2=pd.DataFrame(l,columns=col)
df2
# Out:
#      Format                        European_player European_score  \
# 0     Teams                            Team Europe              5
# 1   Doubles           Darren Appleton & Karl Boyes              3
# 2   Singles                              Mark Gray              3
# 3   Doubles     Niels Feijen & Nikos Ekonomopoulos              5
# 4   Singles                        Darren Appleton              5
# 5   Doubles               Niels Feijen & Mark Gray              2
# 6   Singles                             Karl Boyes              5
# 7   Doubles  Darren Appleton & Nikos Ekonomopoulos              5
# 8   Singles                           Niels Feijen              5
# 9   Doubles            Darren Appleton & Mark Gray              4
# 10  Doubles       Nikos Ekonomopoulos & Karl Boyes              5
# 11  Singles                    Nikos Ekonomopoulos              3
# 12  Doubles                 Mark Gray & Karl Boyes              5
# 13  Singles                           Niels Feijen              5
# 14  Singles                        Darren Appleton              5
# 15  Singles                    Nikos Ekonomopoulos              5
#
#    American_score                     American_player
# 0               1                            Team USA
# 1               5           Corey Deuel & Justin Hall
# 2               5                        John Schmidt
# 3               1  Shane Van Boening & Justin Bergman
# 4               3                   Shane Van Boening
# 5               5        Justin Hall & Justin Bergman
# 6               2                         Corey Deuel
# 7               2    Shane Van Boening & John Schmidt
# 8               3                      Justin Bergman
# 9               5     Shane Van Boening & Corey Deuel
# 10              3          John Schmidt & Justin Hall
# 11              5                         Justin Hall
# 12              3          Corey Deuel & John Schmidt
# 13              2                      Justin Bergman
# 14              2                   Shane Van Boening
# 15              2                   Shane Van Boening

# %%
frames=[df,df2]
df=pd.concat(frames)

# %%
df['Europe_won']=df.European_score>df.American_score

# %%
pkl=r'C:\Users\andrew\Desktop\mosconi\mosconi_1998_2014_inc_pkls'
df.to_pickle(pkl)

# %%
cols= ['Format','European_player','European_score','American_score','American_player','Europe_won']
df=df[cols]

# %% [markdown]
# 2015 Data is backwards, need to fix the order (european player should be first)

# %%
def createdf_bw(tables):
    import re
    l=[]
    col=['Format','European_player','European_score','American_score','American_player']

    for i in range(len(tables)+1):
        for j in range(1,6):
            try:
                element=tables[i][j].text_content().replace("\n", " ")
                match = re.match(r"\s?(\w+)\s(.+)\s([0-9])[–]([0-9])\s?\w+\s?(.+)\s", element)
                if match:
                    print('ok')
                    lst=[match.group(1), match.group(5), match.group(4), match.group(3), match.group(2)]
                    print(lst)
                    l.append(lst)
                else:
                    print('fail')
            except:
                pass
    print(l)
    df=pd.DataFrame(l,columns=col)
    return(df)

# %%
def main_bw():
    from lxml import html
    import requests
    import pandas as pd
    df = pd.DataFrame()
    links = createlinks('2015','2016')
    for url in links:
        tables = createtables(url)
        tl = tablelengths(tables)
        print(tl)
        newdf = createdf_bw(tables) 
        df=df.append(newdf)
    return(df)

# %%
df2015= main_bw()
# Out:
# [5, 5, 5, 3]
# ok
# ['Teams', 'Team Europe', '4', '5', 'Team USA']
# ok
# ['Doubles', 'Karl Boyes Nick van den Berg', '5', '4', 'Corey Deuel Mike Dechaine']
# ok
# ['Singles', 'Niels Feijen', '5', '2', 'Justin Bergman']
# ok
# ['Doubles', 'Darren Appleton Albin Ouschan', '1', '5', 'Shane Van Boening Skyler Woodward']
# ok
# ['Singles', 'Darren Appleton', '5', '1', 'Shane Van Boening']
# ok
# ['Doubles', 'Niels Feijen Nick van den Berg', '3', '5', 'Justin Bergman Skyler Woodward']
# ok
# ['Singles', 'Albin Ouschan', '5', '3', 'Mike Dechaine']
# ok
# ['Doubles', 'Darren Appleton Karl Boyes', '5', '2', 'Shane Van Boening Corey Deuel']
# ok
# ['Singles', 'Karl Boyes', '5', '3', 'Skyler Woodward']
# ok
# ['Doubles', 'Darren Appleton Nick van den Berg', '4', '5', 'Shane Van Boening Mike Dechaine']
# ok
# ['Doubles', 'Niels Feijen Albin Ouschan', '5', '1', 'Justin Bergman Corey Deuel']
# ok
# ['Singles', 'Nick van den Berg', '4', '5', 'Corey Deuel']
# ok
# ['Doubles', 'Karl Boyes Albin Ouschan', '5', '2', 'Mike Dechaine Skyler Woodward']
# ok
# ['Singles', 'Niels Feijen', '5', '4', 'Shane Van Boening']
# ok
# ['Singles', 'Darren Appleton', '2', '5', 'Justin Bergman']
# ok
# ['Singles', 'Niels Feijen', '5', '4', 'Justin Bergman']
# ok
# ['Singles', 'Karl Boyes', '4', '5', 'Shane Van Boening']
# ok
# ['Singles', 'Albin Ouschan', '5', '4', 'Skyler Woodward']
# fail
# fail
# [['Teams', 'Team Europe', '4', '5', 'Team USA'], ['Doubles', 'Karl Boyes Nick van den Berg', '5', '4', 'Corey Deuel Mike Dechaine'], ['Singles', 'Niels Feijen', '5', '2', 'Justin Bergman'], ['Doubles', 'Darren Appleton Albin Ouschan', '1', '5', 'Shane Van Boening Skyler Woodward'], ['Singles', 'Darren Appleton', '5', '1', 'Shane Van Boening'], ['Doubles', 'Niels Feijen Nick van den Berg', '3', '5', 'Justin Bergman Skyler Woodward'], ['Singles', 'Albin Ouschan', '5', '3', 'Mike Dechaine'], ['Doubles', 'Darren Appleton Karl Boyes', '5', '2', 'Shane Van Boening Corey Deuel'], ['Singles', 'Karl Boyes', '5', '3', 'Skyler Woodward'], ['Doubles', 'Darren Appleton Nick van den Berg', '4', '5', 'Shane Van Boening Mike Dechaine'], ['Doubles', 'Niels Feijen Albin Ouschan', '5', '1', 'Justin Bergman Corey Deuel'], ['Singles', 'Nick van den Berg', '4', '5', 'Corey Deuel'], ['Doubles', 'Karl Boyes Albin Ouschan', '5', '2', 'Mike Dechaine Skyler Woodward'], ['Singles', 'Niels Feijen', '5', '4', 'Shane Van Boening'], ['Singles', 'Darren Appleton', '2', '5', 'Justin Bergman'], ['Singles', 'Niels Feijen', '5', '4', 'Justin Bergman'], ['Singles', 'Karl Boyes', '4', '5', 'Shane Van Boening'], ['Singles', 'Albin Ouschan', '5', '4', 'Skyler Woodward']]

# %%
frames=[df,df2015]
df=pd.concat(frames)

# %%
df
# Out:
#                       American_player American_score Europe_won  \
# 0           Johnny Archer Nick Varner              5       True
# 1         James Rempe Earl Strickland              6       True
# 2           Kim Davenport Reed Pierce              7      False
# 3         James Rempe Earl Strickland              3       True
# 4           Nick Varner Johnny Archer              7      False
# 5           Kim Davenport Reed Pierce              5       True
# 6                       Johnny Archer              7      False
# 7                     Earl Strickland              7      False
# 8                         Reed Pierce              7      False
# 9                         Nick Varner              1       True
# 10      Earl Strickland Kim Davenport              7      False
# 11          Johnny Archer Nick Varner              7      False
# 12            Reed Pierce James Rempe              2       True
# 13                      Kim Davenport              7      False
# 14                        James Rempe              7      False
# 15                    Earl Strickland              7      False
# 16                      Johnny Archer              5       True
# 17                        Reed Pierce              7      False
# 18                        Nick Varner              6       True
# 19                        James Rempe              6       True
# 20                      Kim Davenport              7      False
# 21                      Johnny Archer              7      False
# 0         Johnny Archer Kim Davenport              5      False
# 1         Earl Strickland James Rempe              5      False
# 2       Jeremy Jones Michael Coltrain              5      False
# 3         Johnny Archer Kim Davenport              3       True
# 4         Earl Strickland James Rempe              2       True
# 5       Jeremy Jones Michael Coltrain              3       True
# 6                       Kim Davenport              5      False
# 7                     Earl Strickland              2       True
# ..                                ...            ...        ...
# 4                   Shane Van Boening              3       True
# 5        Justin Hall & Justin Bergman              5      False
# 6                         Corey Deuel              2       True
# 7    Shane Van Boening & John Schmidt              2       True
# 8                      Justin Bergman              3       True
# 9     Shane Van Boening & Corey Deuel              5      False
# 10         John Schmidt & Justin Hall              3       True
# 11                        Justin Hall              5      False
# 12         Corey Deuel & John Schmidt              3       True
# 13                     Justin Bergman              2       True
# 14                  Shane Van Boening              2       True
# 15                  Shane Van Boening              2       True
# 0                            Team USA              5        NaN
# 1           Corey Deuel Mike Dechaine              4        NaN
# 2                      Justin Bergman              2        NaN
# 3   Shane Van Boening Skyler Woodward              5        NaN
# 4                   Shane Van Boening              1        NaN
# 5      Justin Bergman Skyler Woodward              5        NaN
# 6                       Mike Dechaine              3        NaN
# 7       Shane Van Boening Corey Deuel              2        NaN
# 8                     Skyler Woodward              3        NaN
# 9     Shane Van Boening Mike Dechaine              5        NaN
# 10         Justin Bergman Corey Deuel              1        NaN
# 11                        Corey Deuel              5        NaN
# 12      Mike Dechaine Skyler Woodward              2        NaN
# 13                  Shane Van Boening              4        NaN
# 14                     Justin Bergman              5        NaN
# 15                     Justin Bergman              4        NaN
# 16                  Shane Van Boening              5        NaN
# 17                    Skyler Woodward              4        NaN
#
#                           European_player European_score   Format
# 0               Mika Immonen Ralf Souquet              7  Doubles
# 1             Oliver Ortmann Steve Knight              7  Doubles
# 2               Fabio Petroni Steve Davis              5  Doubles
# 3               Mika Immonen Ralf Souquet              7  Doubles
# 4               Steve Davis Fabio Petroni              3  Doubles
# 5             Oliver Ortmann Steve Knight              7  Doubles
# 6                          Oliver Ortmann              3  Singles
# 7                            Steve Knight              3  Singles
# 8                            Mika Immonen              4  Singles
# 9                            Ralf Souquet              7  Singles
# 10            Steve Knight Oliver Ortmann              6  Doubles
# 11              Ralf Souquet Mika Immonen              5  Doubles
# 12              Steve Davis Fabio Petroni              7  Doubles
# 13                            Steve Davis              2  Singles
# 14                          Fabio Petroni              5  Singles
# 15                           Mika Immonen              4  Singles
# 16                           Ralf Souquet              7  Singles
# 17                         Oliver Ortmann              4  Singles
# 18                           Steve Knight              7  Singles
# 19                            Steve Davis              7  Singles
# 20                          Fabio Petroni              5  Singles
# 21                           Ralf Souquet              4  Singles
# 0               Mika Immonen Ralf Souquet              2  Doubles
# 1                Oliver Ortmann Alex Lely              2  Doubles
# 2                Steve Davis Steve Knight              4  Doubles
# 3             Ralf Souquet Oliver Ortmann              5  Doubles
# 4               Steve Knight Mika Immonen              5  Doubles
# 5                   Steve Davis Alex Lely              5  Doubles
# 6                               Alex Lely              4  Singles
# 7                            Ralf Souquet              5  Singles
# ..                                    ...            ...      ...
# 4                         Darren Appleton              5  Singles
# 5                Niels Feijen & Mark Gray              2  Doubles
# 6                              Karl Boyes              5  Singles
# 7   Darren Appleton & Nikos Ekonomopoulos              5  Doubles
# 8                            Niels Feijen              5  Singles
# 9             Darren Appleton & Mark Gray              4  Doubles
# 10       Nikos Ekonomopoulos & Karl Boyes              5  Doubles
# 11                    Nikos Ekonomopoulos              3  Singles
# 12                 Mark Gray & Karl Boyes              5  Doubles
# 13                           Niels Feijen              5  Singles
# 14                        Darren Appleton              5  Singles
# 15                    Nikos Ekonomopoulos              5  Singles
# 0                             Team Europe              4    Teams
# 1            Karl Boyes Nick van den Berg              5  Doubles
# 2                            Niels Feijen              5  Singles
# 3           Darren Appleton Albin Ouschan              1  Doubles
# 4                         Darren Appleton              5  Singles
# 5          Niels Feijen Nick van den Berg              3  Doubles
# 6                           Albin Ouschan              5  Singles
# 7              Darren Appleton Karl Boyes              5  Doubles
# 8                              Karl Boyes              5  Singles
# 9       Darren Appleton Nick van den Berg              4  Doubles
# 10             Niels Feijen Albin Ouschan              5  Doubles
# 11                      Nick van den Berg              4  Singles
# 12               Karl Boyes Albin Ouschan              5  Doubles
# 13                           Niels Feijen              5  Singles
# 14                        Darren Appleton              2  Singles
# 15                           Niels Feijen              5  Singles
# 16                             Karl Boyes              4  Singles
# 17                          Albin Ouschan              5  Singles
#
# [335 rows x 6 columns]

# %%
pkl = 'new_inc_2015_fixed'
pd.to_pickle(df,pkl)

# %% [markdown]
# Next steps: Rescrape the data.
#
# 1. Need to include the year as a multiindex and concatenate the frames per year.
# 1. Need to reconfigure the number of rows to possibly extend beyond 5. Have to dynamically learn the number of rows in the    given table and then use that number instead of hard coding it.
# 3. Need to collect the 'team' data each year. I.e. what players are on each team so that I can do analysis on the 'team' matches and include that in the final presentations.
# 4. Scrape location or just see if it changes every year

# %% [markdown]
# 1. Reconfigure number of rows dynamically.
