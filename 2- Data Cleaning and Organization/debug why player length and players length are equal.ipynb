# %%
import sqlite3 as sq

# %%
import pandas as pd

# %%
sql='select * from players'
sql2='select * from player'
con=sq.connect('../players.db')

# %%
players = pd.read_sql(sql,con)

# %%
player = pd.read_sql(sql2,con)

# %%
# for i in [player,players]:
# Out:
#                    Name          Location     Team  Appearances Win-loss-tie  \
# 0         Johnny Archer           Georgia  America           17        9-7-1
# 1       Earl Strickland    North Carolina  America           14        9-4-1
# 2         Rodney Morris        California  America           10        3-6-1
# 3     Shane Van Boening      South Dakota  America           10        1-9-0
# 4           Corey Deuel        California  America            9        3-5-1
# 5          Jeremy Jones             Texas  America            7        5-2-0
# 6      Charlie Williams       South Korea  America            5        4-1-0
# 7           Nick Varner          Kentucky  America            4        3-1-0
# 8         Mike Dechaine             Maine  America            4        0-4-0
# 9          Dennis Hatch          Michigan  America            4        1-3-0
# 10        Kim Davenport          Oklahoma  America            3        3-0-0
# ...

# %%
p = set(list(player['Name']))

# %%
q = set(list(players['Name']))

# %%
p ^ q
# Out:
# {'Billy Thorpe', 'Joshua Filler', 'Ralf Souquet', 'Robert Hunter'}

# %% [markdown]
# Check later= are robert hunter and bobby hunter the same guy?? (fixed)

# %% [markdown]
# Turns out I chopped ralf out on a bad indexing
