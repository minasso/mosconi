# %%
import sqlite3

# %%
import pandas as pd

# %%
con=sqlite3.connect('../players.db')

# %%
sql='select * from players'

# %%
df = pd.read_sql(sql,con)

# %%
df.head()
# Out:
#                 Name        Location     Team  Appearances Win-loss-tie  Wins  \
# 0      Johnny Archer         Georgia  America           17        9-7-1     9
# 1    Earl Strickland  North Carolina  America           14        9-4-1     9
# 2      Rodney Morris      California  America           10        3-6-1     3
# 3  Shane Van Boening    South Dakota  America           10        1-9-0     1
# 4        Corey Deuel      California  America            9        3-5-1     3
#
#    Losses    Pct
# 0       7  52.94
# 1       4  64.29
# 2       6  30.00
# 3       9  10.00
# 4       5  33.33

# %%
df.sort_values('Appearances',ascending=False)
# Out:
#                    Name          Location     Team  Appearances Win-loss-tie  \
# 0         Johnny Archer           Georgia  America           17        9-7-1
# 40         Ralf Souquet           Germany   Europe           16        6-9-1
# 41         Mika Immonen           Finland   Europe           15       4-10-1
# 1       Earl Strickland    North Carolina  America           14        9-4-1
# 42         Niels Feijen       Netherlands   Europe           12        8-4-0
# 43          Steve Davis           England   Europe           11        2-9-0
# 2         Rodney Morris        California  America           10        3-6-1
# 3     Shane Van Boening      South Dakota  America           10        1-9-0
# 4           Corey Deuel        California  America            9        3-5-1
# 44       Oliver Ortmann           Germany   Europe            8        2-6-0
# 45      Darren Appleton           England   Europe            8        7-1-0
# ...
