# %%
import pandas as pd

# %%
import sqlite3

# %%
sql = 'select * from results'

# %%
con = sqlite3.connect('../players.db')

# %%
df = pd.read_sql(sql, con)

# %%
df
# Out:
#      index  Year  Match   Format            European_player European_score  \
# 0        0  1994      0  Singles                  Tom Storm              2
# 1        1  1994      1  Singles             Oliver Ortmann              2
# 2        2  1994      2  Singles                 Lee Tucker              1
# 3        3  1994      3  Singles             Allison Fisher              0
# 4        4  1994      4  Singles                Steve Davis              2
# ..     ...   ...    ...      ...                        ...            ...
# 506    506  2019     14  Doubles  Niels Feijen, Jayson Shaw              5
# 507    507  2019     15  Singles                Jayson Shaw              3
# 508    508  2019     16  Singles                Eklent Kaçi              5
# 509    509  2019     17  Singles          Alexander Kazakis              3
# 510    510  2019     18  Singles              Joshua Filler              3
#
#     American_score               American_player  Europe_won
# ...
