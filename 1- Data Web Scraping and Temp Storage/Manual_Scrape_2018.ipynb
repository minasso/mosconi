# %%
import pandas as pd

# %%
file = 'mosconi_2018.csv'

# %%
df = pd.read_csv(file)

# %%
df.columns=['eu_player','score','am_player']

# %%
df['score'][0]='5–4'

# %%
df['format']=df['eu_player']

# %%
formats=['Doubles','Singles','Teams']

# %%
df = df.fillna(method='ffill')

# %%
import numpy as np

# %%
df['format'][0]='Teams'

# %%
df
# Out:
#             eu_player score          am_player             format
# 0         Team Europe   5–4           Team USA              Teams
# 1             Doubles   5–1            Doubles            Doubles
# 2       Albin Ouschan   5–1       Billy Thorpe      Albin Ouschan
# 3         Jayson Shaw   5–1    Skyler Woodward        Jayson Shaw
# 4             Singles   3–5            Singles            Singles
# 5        Niels Feijen   3–5        Tyler Styer       Niels Feijen
# 6             Doubles   1–5            Doubles            Doubles
# 7         Eklent Kaci   1–5  Shane Van Boening        Eklent Kaci
# 8   Alexander Kazakis   1–5        Corey Deuel  Alexander Kazakis
# 9             Singles   0–5            Singles            Singles
# 10        Jayson Shaw   0–5  Shane Van Boening        Jayson Shaw
# 11            Singles   5–2            Singles            Singles
# 12        Jayson Shaw   5–2  Shane Van Boening        Jayson Shaw
# ...

# %%
df['format']=df['format'].apply(lambda x: x if x in formats else np.nan)

# %%
df
# Out:
#             eu_player score          am_player   format
# 0         Team Europe   5–4           Team USA    Teams
# 1             Doubles   5–1            Doubles  Doubles
# 2       Albin Ouschan   5–1       Billy Thorpe      NaN
# 3         Jayson Shaw   5–1    Skyler Woodward      NaN
# 4             Singles   3–5            Singles  Singles
# 5        Niels Feijen   3–5        Tyler Styer      NaN
# 6             Doubles   1–5            Doubles  Doubles
# 7         Eklent Kaci   1–5  Shane Van Boening      NaN
# 8   Alexander Kazakis   1–5        Corey Deuel      NaN
# 9             Singles   0–5            Singles  Singles
# 10        Jayson Shaw   0–5  Shane Van Boening      NaN
# 11            Singles   5–2            Singles  Singles
# 12        Jayson Shaw   5–2  Shane Van Boening      NaN
# 13            Doubles   3–5            Doubles  Doubles
# 14       Niels Feijen   3–5    Skyler Woodward      NaN
# 15  Alexander Kazakis   3–5  Shane Van Boening      NaN
# ...

# %%
df = df.fillna(method='ffill')

# %%
df = df[df['eu_player'].apply(lambda x: x not in formats)]

# %%
df = df.reset_index(drop=True)

# %%
df = df.reset_index()

# %%
df.columns = ['match', 'eu_player', 'score', 'am_player', 'format']

# %%
df['match']=df['match']+1

# %%
df
# Out:
#     match          eu_player score          am_player   format
# 0       1        Team Europe   5–4           Team USA    Teams
# 1       2      Albin Ouschan   5–1       Billy Thorpe  Doubles
# 2       3        Jayson Shaw   5–1    Skyler Woodward  Doubles
# 3       4       Niels Feijen   3–5        Tyler Styer  Singles
# 4       5        Eklent Kaci   1–5  Shane Van Boening  Doubles
# 5       6  Alexander Kazakis   1–5        Corey Deuel  Doubles
# 6       7        Jayson Shaw   0–5  Shane Van Boening  Singles
# 7       8        Jayson Shaw   5–2  Shane Van Boening  Singles
# 8       9       Niels Feijen   3–5    Skyler Woodward  Doubles
# 9      10  Alexander Kazakis   3–5  Shane Van Boening  Doubles
# 10     11      Albin Ouschan   5–3        Corey Deuel  Singles
# 11     12        Eklent Kaci   2–5       Billy Thorpe  Doubles
# 12     13        Jayson Shaw   2–5        Tyler Styer  Doubles
# 13     14        Eklent Kaci   3–5       Billy Thorpe  Singles
# ...

# %%
dub = df[df.format=='Doubles']

# %%
dub
# Out:
#     match          eu_player score          am_player   format
# 1       2      Albin Ouschan   5–1       Billy Thorpe  Doubles
# 2       3        Jayson Shaw   5–1    Skyler Woodward  Doubles
# 4       5        Eklent Kaci   1–5  Shane Van Boening  Doubles
# 5       6  Alexander Kazakis   1–5        Corey Deuel  Doubles
# 8       9       Niels Feijen   3–5    Skyler Woodward  Doubles
# 9      10  Alexander Kazakis   3–5  Shane Van Boening  Doubles
# 11     12        Eklent Kaci   2–5       Billy Thorpe  Doubles
# 12     13        Jayson Shaw   2–5        Tyler Styer  Doubles
# 14     15       Niels Feijen   4–5    Skyler Woodward  Doubles
# 15     16      Albin Ouschan   4–5        Tyler Styer  Doubles
# 17     18        Eklent Kaci   5–4        Tyler Styer  Doubles
# 18     19       Niels Feijen   5–4        Corey Deuel  Doubles
# 20     21  Alexander Kazakis   5–1  Shane Van Boening  Doubles
# 21     22      Albin Ouschan   5–1       Billy Thorpe  Doubles

# %%
other=df[df.format!='Doubles']

# %%
dub
# Out:
#     match          eu_player score          am_player   format
# 1       2      Albin Ouschan   5–1       Billy Thorpe  Doubles
# 2       3        Jayson Shaw   5–1    Skyler Woodward  Doubles
# 4       5        Eklent Kaci   1–5  Shane Van Boening  Doubles
# 5       6  Alexander Kazakis   1–5        Corey Deuel  Doubles
# 8       9       Niels Feijen   3–5    Skyler Woodward  Doubles
# 9      10  Alexander Kazakis   3–5  Shane Van Boening  Doubles
# 11     12        Eklent Kaci   2–5       Billy Thorpe  Doubles
# 12     13        Jayson Shaw   2–5        Tyler Styer  Doubles
# 14     15       Niels Feijen   4–5    Skyler Woodward  Doubles
# 15     16      Albin Ouschan   4–5        Tyler Styer  Doubles
# 17     18        Eklent Kaci   5–4        Tyler Styer  Doubles
# 18     19       Niels Feijen   5–4        Corey Deuel  Doubles
# 20     21  Alexander Kazakis   5–1  Shane Van Boening  Doubles
# 21     22      Albin Ouschan   5–1       Billy Thorpe  Doubles

# %%
dub1 = dub.iloc[::2]

# %%
dub2 = dub.iloc[1::2]

# %%
dub1
# Out:
#     match          eu_player score          am_player   format
# 1       2      Albin Ouschan   5–1       Billy Thorpe  Doubles
# 4       5        Eklent Kaci   1–5  Shane Van Boening  Doubles
# 8       9       Niels Feijen   3–5    Skyler Woodward  Doubles
# 11     12        Eklent Kaci   2–5       Billy Thorpe  Doubles
# 14     15       Niels Feijen   4–5    Skyler Woodward  Doubles
# 17     18        Eklent Kaci   5–4        Tyler Styer  Doubles
# 20     21  Alexander Kazakis   5–1  Shane Van Boening  Doubles

# %%
dub2
# Out:
#     match          eu_player score          am_player   format
# 2       3        Jayson Shaw   5–1    Skyler Woodward  Doubles
# 5       6  Alexander Kazakis   1–5        Corey Deuel  Doubles
# 9      10  Alexander Kazakis   3–5  Shane Van Boening  Doubles
# 12     13        Jayson Shaw   2–5        Tyler Styer  Doubles
# 15     16      Albin Ouschan   4–5        Tyler Styer  Doubles
# 18     19       Niels Feijen   5–4        Corey Deuel  Doubles
# 21     22      Albin Ouschan   5–1       Billy Thorpe  Doubles

# %%
dub1=dub1.reset_index()
dub2=dub2.reset_index()

# %%
dub1
# Out:
#    index  match          eu_player score          am_player   format
# 0      1      2      Albin Ouschan   5–1       Billy Thorpe  Doubles
# 1      4      5        Eklent Kaci   1–5  Shane Van Boening  Doubles
# 2      8      9       Niels Feijen   3–5    Skyler Woodward  Doubles
# 3     11     12        Eklent Kaci   2–5       Billy Thorpe  Doubles
# 4     14     15       Niels Feijen   4–5    Skyler Woodward  Doubles
# 5     17     18        Eklent Kaci   5–4        Tyler Styer  Doubles
# 6     20     21  Alexander Kazakis   5–1  Shane Van Boening  Doubles

# %%
dub2.columns=['index2', 'match2', 'eu_player2', 'score2', 'am_player2', 'format2']

# %%
d = pd.concat([dub1,dub2],axis=1)

# %%
d['eu']=d['eu_player']+', '+d['eu_player2']
d['am']=d['am_player']+', '+d['am_player2']

# %%
d
# Out:
#    index  match          eu_player score          am_player   format  index2  \
# 0      1      2      Albin Ouschan   5–1       Billy Thorpe  Doubles       2
# 1      4      5        Eklent Kaci   1–5  Shane Van Boening  Doubles       5
# 2      8      9       Niels Feijen   3–5    Skyler Woodward  Doubles       9
# 3     11     12        Eklent Kaci   2–5       Billy Thorpe  Doubles      12
# 4     14     15       Niels Feijen   4–5    Skyler Woodward  Doubles      15
# 5     17     18        Eklent Kaci   5–4        Tyler Styer  Doubles      18
# 6     20     21  Alexander Kazakis   5–1  Shane Van Boening  Doubles      21
#
#    match2         eu_player2 score2         am_player2  format2  \
# 0       3        Jayson Shaw    5–1    Skyler Woodward  Doubles
# 1       6  Alexander Kazakis    1–5        Corey Deuel  Doubles
# 2      10  Alexander Kazakis    3–5  Shane Van Boening  Doubles
# 3      13        Jayson Shaw    2–5        Tyler Styer  Doubles
# ...

# %%
cols = ['index','match','format', 'eu', 'score', 'am']

# %%
d=d[cols]

# %%
d.columns=['index', 'match', 'format', 'eu_player', 'score', 'am_player']

# %%
c=['match', 'eu_player', 'score', 'am_player','format']

# %%
d=d[c]

# %%
d
# Out:
#    match                         eu_player score  \
# 0      2        Albin Ouschan, Jayson Shaw   5–1
# 1      5    Eklent Kaci, Alexander Kazakis   1–5
# 2      9   Niels Feijen, Alexander Kazakis   3–5
# 3     12          Eklent Kaci, Jayson Shaw   2–5
# 4     15       Niels Feijen, Albin Ouschan   4–5
# 5     18         Eklent Kaci, Niels Feijen   5–4
# 6     21  Alexander Kazakis, Albin Ouschan   5–1
#
#                             am_player   format
# 0       Billy Thorpe, Skyler Woodward  Doubles
# 1      Shane Van Boening, Corey Deuel  Doubles
# 2  Skyler Woodward, Shane Van Boening  Doubles
# 3           Billy Thorpe, Tyler Styer  Doubles
# 4        Skyler Woodward, Tyler Styer  Doubles
# 5            Tyler Styer, Corey Deuel  Doubles
# 6     Shane Van Boening, Billy Thorpe  Doubles

# %%
other
# Out:
#     match          eu_player score          am_player   format
# 0       1        Team Europe   5–4           Team USA    Teams
# 3       4       Niels Feijen   3–5        Tyler Styer  Singles
# 6       7        Jayson Shaw   0–5  Shane Van Boening  Singles
# 7       8        Jayson Shaw   5–2  Shane Van Boening  Singles
# 10     11      Albin Ouschan   5–3        Corey Deuel  Singles
# 13     14        Eklent Kaci   3–5       Billy Thorpe  Singles
# 16     17  Alexander Kazakis   3–5    Skyler Woodward  Singles
# 19     20        Jayson Shaw   4–5    Skyler Woodward  Singles
# 22     23      Albin Ouschan   4–5    Skyler Woodward  Singles
# 23     24        Jayson Shaw   5–3        Tyler Styer  Singles
# 24     25       Niels Feijen   5–1        Corey Deuel  Singles
# 25     26        Eklent Kaci   5–2       Billy Thorpe  Singles
# 26     27  Alexander Kazakis   3–5  Shane Van Boening  Singles

# %%
new = pd.concat([d,other]).sort_values('match')

# %%
new = new.reset_index(drop=True)

# %%
new = new.reset_index()

# %%
new['match']=new['index']+1

# %%
new = new[['match', 'eu_player', 'score', 'am_player', 'format']]

# %%
new
# Out:
#     match                         eu_player score  \
# 0       1                       Team Europe   5–4
# 1       2        Albin Ouschan, Jayson Shaw   5–1
# 2       3                      Niels Feijen   3–5
# 3       4    Eklent Kaci, Alexander Kazakis   1–5
# 4       5                       Jayson Shaw   0–5
# 5       6                       Jayson Shaw   5–2
# 6       7   Niels Feijen, Alexander Kazakis   3–5
# 7       8                     Albin Ouschan   5–3
# 8       9          Eklent Kaci, Jayson Shaw   2–5
# 9      10                       Eklent Kaci   3–5
# 10     11       Niels Feijen, Albin Ouschan   4–5
# 11     12                 Alexander Kazakis   3–5
# 12     13         Eklent Kaci, Niels Feijen   5–4
# 13     14                       Jayson Shaw   4–5
# 14     15  Alexander Kazakis, Albin Ouschan   5–1
# 15     16                     Albin Ouschan   4–5
# 16     17                       Jayson Shaw   5–3
# 17     18                      Niels Feijen   5–1
# ...

# %%
new['eu_score']=new['score'].str[0]

# %%
new['am_score']=new['score'].str[-1]

# %%
new
# Out:
#     match                         eu_player score  \
# 0       1                       Team Europe   5–4
# 1       2        Albin Ouschan, Jayson Shaw   5–1
# 2       3                      Niels Feijen   3–5
# 3       4    Eklent Kaci, Alexander Kazakis   1–5
# 4       5                       Jayson Shaw   0–5
# 5       6                       Jayson Shaw   5–2
# 6       7   Niels Feijen, Alexander Kazakis   3–5
# 7       8                     Albin Ouschan   5–3
# 8       9          Eklent Kaci, Jayson Shaw   2–5
# 9      10                       Eklent Kaci   3–5
# 10     11       Niels Feijen, Albin Ouschan   4–5
# 11     12                 Alexander Kazakis   3–5
# 12     13         Eklent Kaci, Niels Feijen   5–4
# 13     14                       Jayson Shaw   4–5
# 14     15  Alexander Kazakis, Albin Ouschan   5–1
# 15     16                     Albin Ouschan   4–5
# 16     17                       Jayson Shaw   5–3
# 17     18                      Niels Feijen   5–1
# ...

# %%
import sqlite3

# %%
con = sqlite3.connect('../players.db')

# %%
sql = 'select * from results'

# %%
df = pd.read_sql(sql,con)

# %%
df.columns=['index', 'Year', 'Match', 'Format', 'European_player', 'European_score',
       'American_score', 'American_player', 'Europe_won']

# %%
df = df[['Year', 'Match', 'Format', 'European_player', 'European_score',
       'American_score', 'American_player', 'Europe_won']]

# %%
new['match']=new['match']-1

# %%
new['Year']='2018'

# %%
new.columns=['Match', 'European_player', 'score', 'American_player', 'Format', 'European_score',
       'American_score', 'Year']

# %%
new['Europe_won']= new['European_score']>new['American_score']

# %%
df
# Out:
#      Year  Match   Format                                    European_player  \
# 0    1994      0  Singles                                          Tom Storm
# 1    1994      1  Singles                                     Oliver Ortmann
# 2    1994      2  Singles                                         Lee Tucker
# 3    1994      3  Singles                                     Allison Fisher
# 4    1994      4  Singles                                        Steve Davis
# 5    1994      5  Singles                                          Tom Storm
# 6    1994      6  Doubles                       Ralf Souquet Franziska Stark
# 7    1994      7  Singles                                         Lee Tucker
# 8    1994      8  Singles                                    Franziska Stark
# 9    1994      9  Singles                                       Ralf Souquet
# 10   1994     10  Doubles                      Oliver Ortmann Allison Fisher
# ...

# %%
new['Europe_won']=new['Europe_won'].apply(lambda x: 1 if x==True else 0)

# %%
new
# Out:
#     Match                   European_player score  \
# 0       0                       Team Europe   5–4
# 1       1        Albin Ouschan, Jayson Shaw   5–1
# 2       2                      Niels Feijen   3–5
# 3       3    Eklent Kaci, Alexander Kazakis   1–5
# 4       4                       Jayson Shaw   0–5
# 5       5                       Jayson Shaw   5–2
# 6       6   Niels Feijen, Alexander Kazakis   3–5
# 7       7                     Albin Ouschan   5–3
# 8       8          Eklent Kaci, Jayson Shaw   2–5
# 9       9                       Eklent Kaci   3–5
# 10     10       Niels Feijen, Albin Ouschan   4–5
# 11     11                 Alexander Kazakis   3–5
# 12     12         Eklent Kaci, Niels Feijen   5–4
# 13     13                       Jayson Shaw   4–5
# 14     14  Alexander Kazakis, Albin Ouschan   5–1
# 15     15                     Albin Ouschan   4–5
# 16     16                       Jayson Shaw   5–3
# 17     17                      Niels Feijen   5–1
# ...

# %%
cols=df.columns

# %%
cols
# Out:
# Index(['Year', 'Match', 'Format', 'European_player', 'European_score',
#        'American_score', 'American_player', 'Europe_won'],
#       dtype='object')

# %%
new.columns = ['Match','European_player','score','American_player','Format','European_score','American_score','Year','Europe_won']

# %%
new = new[['Year','Match','Format', 'European_player', 'European_score','American_score', 'American_player'
       ,'Europe_won']]

# %%
new
# Out:
#     Year  Match   Format                   European_player European_score  \
# 0   2018      0    Teams                       Team Europe              5
# 1   2018      1  Doubles        Albin Ouschan, Jayson Shaw              5
# 2   2018      2  Singles                      Niels Feijen              3
# 3   2018      3  Doubles    Eklent Kaci, Alexander Kazakis              1
# 4   2018      4  Singles                       Jayson Shaw              0
# 5   2018      5  Singles                       Jayson Shaw              5
# 6   2018      6  Doubles   Niels Feijen, Alexander Kazakis              3
# 7   2018      7  Singles                     Albin Ouschan              5
# 8   2018      8  Doubles          Eklent Kaci, Jayson Shaw              2
# 9   2018      9  Singles                       Eklent Kaci              3
# 10  2018     10  Doubles       Niels Feijen, Albin Ouschan              4
# 11  2018     11  Singles                 Alexander Kazakis              3
# ...

# %%
new.loc[0,'American_player']='Billy Thorpe, Skyler Woodward, Tyler Styer, Shane Van Boening, Corey Deuel'

# %%
new.loc[0,'European_player']='Albin Ouschan, Jayson Shaw, Niels Feijen, Eklent Kaci, Alexander Kazakis'
# Out:
# C:\Users\Andrew\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
new
# Out:
#     Year  Match   Format                                    European_player  \
# 0   2018      0    Teams  Albin Ouschan, Jayson Shaw, Niels Feijen, Ekle...
# 1   2018      1  Doubles                         Albin Ouschan, Jayson Shaw
# 2   2018      2  Singles                                       Niels Feijen
# 3   2018      3  Doubles                     Eklent Kaci, Alexander Kazakis
# 4   2018      4  Singles                                        Jayson Shaw
# 5   2018      5  Singles                                        Jayson Shaw
# 6   2018      6  Doubles                    Niels Feijen, Alexander Kazakis
# 7   2018      7  Singles                                      Albin Ouschan
# 8   2018      8  Doubles                           Eklent Kaci, Jayson Shaw
# 9   2018      9  Singles                                        Eklent Kaci
# 10  2018     10  Doubles                        Niels Feijen, Albin Ouschan
# ...

# %%
df
# Out:
#      Year  Match   Format                                    European_player  \
# 0    1994      0  Singles                                          Tom Storm
# 1    1994      1  Singles                                     Oliver Ortmann
# 2    1994      2  Singles                                         Lee Tucker
# 3    1994      3  Singles                                     Allison Fisher
# 4    1994      4  Singles                                        Steve Davis
# 5    1994      5  Singles                                          Tom Storm
# 6    1994      6  Doubles                       Ralf Souquet Franziska Stark
# 7    1994      7  Singles                                         Lee Tucker
# 8    1994      8  Singles                                    Franziska Stark
# 9    1994      9  Singles                                       Ralf Souquet
# 10   1994     10  Doubles                      Oliver Ortmann Allison Fisher
# ...

# %%
f = pd.concat([df,new])

# %%
f.reset_index(drop=True,inplace=True)

# %%
f
# Out:
#      Year  Match   Format                                    European_player  \
# 0    1994      0  Singles                                          Tom Storm
# 1    1994      1  Singles                                     Oliver Ortmann
# 2    1994      2  Singles                                         Lee Tucker
# 3    1994      3  Singles                                     Allison Fisher
# 4    1994      4  Singles                                        Steve Davis
# 5    1994      5  Singles                                          Tom Storm
# 6    1994      6  Doubles                       Ralf Souquet Franziska Stark
# 7    1994      7  Singles                                         Lee Tucker
# 8    1994      8  Singles                                    Franziska Stark
# 9    1994      9  Singles                                       Ralf Souquet
# 10   1994     10  Doubles                      Oliver Ortmann Allison Fisher
# ...

# %%
f.to_sql('results',con,if_exists='replace')

# %%
con.close()
